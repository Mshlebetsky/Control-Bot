# %%
import pandas as pd
data = pd.read_csv("../rulate_books.csv")
data.tail()
# Out:
#                                           original_title  \
# 64572  Naruto: Gou arrived and the Nine-Tails attacke...
# 64573                            Акума-Пустотелый Демон
# 64574                                    Система Тренера
# 64575                          Doomsday of Akame ga Kill
# 64576                          I! The Infinite Emperor!
#
#                                                    title  \
# 64572  Naruto: Gou arrived and the Nine-Tails attacke...
# 64573    Акума-Пустотелый Демон / Акума, яростный пустой
# 64574                                    Система Тренера
# 64575                          Doomsday of Akame ga Kill
# 64576  I! The Infinite Emperor! / Я! Бесконечный импе...
#
#                                         translated_title  \
# 64572   Наруто: Гоу прибыл, и Девятихвостые напали на...
# 64573                             Акума, яростный пустой
# 64574                                                NaN
# ...

# %%
data.shape
# Out:
# (64577, 17)

# %%
data[data["title"].str.contains("Apocalypse: After Hoarding Tens of Millions")]
# Out:
#                                           original_title  \
# 54257  Apocalypse: After Hoarding Tens of Millions of...
#
#                                                    title  \
# 54257  Apocalypse: After Hoarding Tens of Millions of...
#
#                                         translated_title  \
# 54257   Апокалипсис: Запасшись Припасами на Десятки М...
#
#                                    link chapters total_pages    rating likes  \
# 54257  https://tl.rulate.ru/book/143804  44 / 30         200  4.9 / 21    24
#
#         category author_name                        author_link  \
# 54257  Китайские    balastik  https://tl.rulate.ru/users/558981
#
#           last_activity                                             genres  \
# 54257  19.08.2025 04:28  боевик, боевые искусства, постапокалиптика, пр...
#
#                                                     tags  fandoms  \
# 54257  авантюристы, выживание, постапокалипсис, сражения      NaN
#
# ...
