# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
data = pd.read_csv("../rulate_books.csv")
data = data.drop_duplicates(subset=['link'])
data.shape
# Out:
# (70310, 17)

# %%
data["likes"] = pd.to_numeric(data["likes"], errors="coerce")
data[(data["title"].str.contains(""))].shape
# Out:
# (70310, 17)

# %%
# data[data['translation_status']=="Заморожено"]
# Out:
# Empty DataFrame
# Columns: [original_title, title, translated_title, link, chapters, total_pages, rating, likes, category, author_name, author_link, last_activity, genres, tags, fandoms, translation_status, description]
# Index: []

# %%
from undetected_chromedriver import Chrome, ChromeOptions
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep

driver = Chrome()
driver.get("https://www.webnovel.com/book/dxd-fusion_33161981500222805")
# url = "https://www.webnovel.com/book/re-goblin--rise-of-the-evolving-monster_33426408208337005"
# driver.get(url)
sleep(1)
driver.find_element(By.ID, "j_read").click()
sleep(2)
condition = True
while (condition):
    condition = float(driver.find_element(By.CLASS_NAME, "cha-hd-progress.j_progress.fr").text.replace("%", "")) < 100
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    sleep(0.5)
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.PAGE_UP)
    sleep(0.5)

# %%
content = driver.find_elements(By.CLASS_NAME, "cha-content ")
chapters = []
texts = []
for chapter in content:
    chapters.append(chapter.find_element(By.XPATH, "..").get_attribute("data-chaptername"))
    texts.append(chapter.find_element(By.CLASS_NAME, "cha-words ").text)

# %%
len(texts), len(chapters)
if len(texts) == len(chapters):
    title = driver.find_element(By.CLASS_NAME, "dib.ell.vam.c_000").text.replace(":", " ")
    text = "\n\n".join([f"{chapters[i]}\n\n{texts[i]}" for i in range(len(texts))])
    with open(f"{title}.txt", "w", encoding="utf-8") as f:
        f.write(text)

# %%
from deep_translator import GoogleTranslator

translator = GoogleTranslator(source='en', target='ru')
translated = translator.translate(text[:1000])
print(translated)
# Out:
# Глава 1: Слияние
#
# Катушки магнитного поля тихо запели, достигнув рабочей мощности.
# Со своего поста в комнате управления термоядерным синтезом Скотти Гарднер смотрел на показания плазмы на центральном дисплее; идеальный, стабильный эллипс, вращающийся в реальном времени, запертый в вакуумной камере реактора. Именно там, где оно должно быть.
# [Температура плазмы держится на уровне 152 миллионов Кельвинов.]
# [Магнитное удерживающее поле на уровне 98,7%.]
# [Нейтронный поток номинальный.]
# Он не моргнул, всматриваясь глазами в показания, перескакивая с одного экрана на другой.
# «Сохраняйте текущие параметры в течение следующих трех минут», — сказал он ровным и точным голосом.
# ...

# %%
from deepl_translator import translate
# translated = translate(text[:1000], source_language="en", target_language="ru", auth_key="")
print(translated)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 from deepl_translator import translate
# ----> 2 translated = translate(text[:1000], source_language="en", target_language="ru")
#       3 print(translated)
#
# TypeError: translate_text() missing 1 required positional argument: 'auth_key'
